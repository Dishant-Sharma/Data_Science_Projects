# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd 
import numpy as np
Iris=pd.read_csv("Iris_external.csv")

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
Iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
top_10=Iris.head(n=10)
print(top_10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
bottom_10=Iris.tail(n=10)
print(bottom_10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.reset_index(col_level=0)
# Out:
#      index  Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0        0                   5.1                  3.5                   1.4
# 1        1                   4.9                  3.0                   1.4
# 2        2                   4.7                  3.2                   1.3
# 3        3                   4.6                  3.1                   1.5
# 4        4                   5.0                  3.6                   1.4
# 5        5                   5.4                  3.9                   1.7
# 6        6                   4.6                  3.4                   1.4
# 7        7                   5.0                  3.4                   1.5
# 8        8                   4.4                  2.9                   1.4
# 9        9                   4.9                  3.1                   1.5
# 10      10                   5.4                  3.7                   1.5
# 11      11                   4.8                  3.4                   1.6
# 12      12                   4.8                  3.0                   1.4
# 13      13                   4.3                  3.0                   1.1
# 14      14                   5.8                  4.0                   1.2
# 15      15                   5.7                  4.4                   1.5
# 16      16                   5.4                  3.9                   1.3
# 17      17                   5.1                  3.5                   1.4
# 18      18                   5.7                  3.8                   1.7
# 19      19                   5.1                  3.8                   1.5
# 20      20                   5.4                  3.4                   1.7
# 21      21                   5.1                  3.7                   1.5
# 22      22                   4.6                  3.6                   1.0
# 23      23                   5.1                  3.3                   1.7
# 24      24                   4.8                  3.4                   1.9
# 25      25                   5.0                  3.0                   1.6
# 26      26                   5.0                  3.4                   1.6
# 27      27                   5.2                  3.5                   1.5
# 28      28                   5.2                  3.4                   1.4
# 29      29                   4.7                  3.2                   1.6
# ..     ...                   ...                  ...                   ...
# 120    120                   6.9                  3.2                   5.7
# 121    121                   5.6                  2.8                   4.9
# 122    122                   7.7                  2.8                   6.7
# 123    123                   6.3                  2.7                   4.9
# 124    124                   6.7                  3.3                   5.7
# 125    125                   7.2                  3.2                   6.0
# 126    126                   6.2                  2.8                   4.8
# 127    127                   6.1                  3.0                   4.9
# 128    128                   6.4                  2.8                   5.6
# 129    129                   7.2                  3.0                   5.8
# 130    130                   7.4                  2.8                   6.1
# 131    131                   7.9                  3.8                   6.4
# 132    132                   6.4                  2.8                   5.6
# 133    133                   6.3                  2.8                   5.1
# 134    134                   6.1                  2.6                   5.6
# 135    135                   7.7                  3.0                   6.1
# 136    136                   6.3                  3.4                   5.6
# 137    137                   6.4                  3.1                   5.5
# 138    138                   6.0                  3.0                   4.8
# 139    139                   6.9                  3.1                   5.4
# 140    140                   6.7                  3.1                   5.6
# 141    141                   6.9                  3.1                   5.1
# 142    142                   5.8                  2.7                   5.1
# 143    143                   6.8                  3.2                   5.9
# 144    144                   6.7                  3.3                   5.7
# 145    145                   6.7                  3.0                   5.2
# 146    146                   6.3                  2.5                   5.0
# 147    147                   6.5                  3.0                   5.2
# 148    148                   6.2                  3.4                   5.4
# 149    149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# 5                    0.4     Iris-setosa
# 6                    0.3     Iris-setosa
# 7                    0.2     Iris-setosa
# 8                    0.2     Iris-setosa
# 9                    0.1     Iris-setosa
# 10                   0.2     Iris-setosa
# 11                   0.2     Iris-setosa
# 12                   0.1     Iris-setosa
# 13                   0.1     Iris-setosa
# 14                   0.2     Iris-setosa
# 15                   0.4     Iris-setosa
# 16                   0.4     Iris-setosa
# 17                   0.3     Iris-setosa
# 18                   0.3     Iris-setosa
# 19                   0.3     Iris-setosa
# 20                   0.2     Iris-setosa
# 21                   0.4     Iris-setosa
# 22                   0.2     Iris-setosa
# 23                   0.5     Iris-setosa
# 24                   0.2     Iris-setosa
# 25                   0.2     Iris-setosa
# 26                   0.4     Iris-setosa
# 27                   0.2     Iris-setosa
# 28                   0.2     Iris-setosa
# 29                   0.2     Iris-setosa
# ..                   ...             ...
# 120                  2.3  Iris-virginica
# 121                  2.0  Iris-virginica
# 122                  2.0  Iris-virginica
# 123                  1.8  Iris-virginica
# 124                  2.1  Iris-virginica
# 125                  1.8  Iris-virginica
# 126                  1.8  Iris-virginica
# 127                  1.8  Iris-virginica
# 128                  2.1  Iris-virginica
# 129                  1.6  Iris-virginica
# 130                  1.9  Iris-virginica
# 131                  2.0  Iris-virginica
# 132                  2.2  Iris-virginica
# 133                  1.5  Iris-virginica
# 134                  1.4  Iris-virginica
# 135                  2.3  Iris-virginica
# 136                  2.4  Iris-virginica
# 137                  1.8  Iris-virginica
# 138                  1.8  Iris-virginica
# 139                  2.1  Iris-virginica
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
Iris.reset_index(col_level=0,drop=True)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 14                    5.8                  4.0                   1.2
# 15                    5.7                  4.4                   1.5
# 16                    5.4                  3.9                   1.3
# 17                    5.1                  3.5                   1.4
# 18                    5.7                  3.8                   1.7
# 19                    5.1                  3.8                   1.5
# 20                    5.4                  3.4                   1.7
# 21                    5.1                  3.7                   1.5
# 22                    4.6                  3.6                   1.0
# 23                    5.1                  3.3                   1.7
# 24                    4.8                  3.4                   1.9
# 25                    5.0                  3.0                   1.6
# 26                    5.0                  3.4                   1.6
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# ..                    ...                  ...                   ...
# 120                   6.9                  3.2                   5.7
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 123                   6.3                  2.7                   4.9
# 124                   6.7                  3.3                   5.7
# 125                   7.2                  3.2                   6.0
# 126                   6.2                  2.8                   4.8
# 127                   6.1                  3.0                   4.9
# 128                   6.4                  2.8                   5.6
# 129                   7.2                  3.0                   5.8
# 130                   7.4                  2.8                   6.1
# 131                   7.9                  3.8                   6.4
# 132                   6.4                  2.8                   5.6
# 133                   6.3                  2.8                   5.1
# 134                   6.1                  2.6                   5.6
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 137                   6.4                  3.1                   5.5
# 138                   6.0                  3.0                   4.8
# 139                   6.9                  3.1                   5.4
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# 5                    0.4     Iris-setosa
# 6                    0.3     Iris-setosa
# 7                    0.2     Iris-setosa
# 8                    0.2     Iris-setosa
# 9                    0.1     Iris-setosa
# 10                   0.2     Iris-setosa
# 11                   0.2     Iris-setosa
# 12                   0.1     Iris-setosa
# 13                   0.1     Iris-setosa
# 14                   0.2     Iris-setosa
# 15                   0.4     Iris-setosa
# 16                   0.4     Iris-setosa
# 17                   0.3     Iris-setosa
# 18                   0.3     Iris-setosa
# 19                   0.3     Iris-setosa
# 20                   0.2     Iris-setosa
# 21                   0.4     Iris-setosa
# 22                   0.2     Iris-setosa
# 23                   0.5     Iris-setosa
# 24                   0.2     Iris-setosa
# 25                   0.2     Iris-setosa
# 26                   0.4     Iris-setosa
# 27                   0.2     Iris-setosa
# 28                   0.2     Iris-setosa
# 29                   0.2     Iris-setosa
# ..                   ...             ...
# 120                  2.3  Iris-virginica
# 121                  2.0  Iris-virginica
# 122                  2.0  Iris-virginica
# 123                  1.8  Iris-virginica
# 124                  2.1  Iris-virginica
# 125                  1.8  Iris-virginica
# 126                  1.8  Iris-virginica
# 127                  1.8  Iris-virginica
# 128                  2.1  Iris-virginica
# 129                  1.6  Iris-virginica
# 130                  1.9  Iris-virginica
# 131                  2.0  Iris-virginica
# 132                  2.2  Iris-virginica
# 133                  1.5  Iris-virginica
# 134                  1.4  Iris-virginica
# 135                  2.3  Iris-virginica
# 136                  2.4  Iris-virginica
# 137                  1.8  Iris-virginica
# 138                  1.8  Iris-virginica
# 139                  2.1  Iris-virginica
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
Iris.iloc[:,2] 
# for someone who reads the data will observe Petal length (in cm) to be the third columns but we have indexing applied from 0 
# onwards to the column of a dataframe that's why i have mentioned 2 as the index to get the third column ie Petal length(in cm)
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.loc[0:10, ['Sepal Length (in cm)', 'Sepal Width in (cm)']]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)
# 0                    5.1                  3.5
# 1                    4.9                  3.0
# 2                    4.7                  3.2
# 3                    4.6                  3.1
# 4                    5.0                  3.6
# 5                    5.4                  3.9
# 6                    4.6                  3.4
# 7                    5.0                  3.4
# 8                    4.4                  2.9
# 9                    4.9                  3.1
# 10                   5.4                  3.7

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris.loc[Iris['Class'] == 'Iris-setosa']
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                    5.1                  3.5                   1.4
# 1                    4.9                  3.0                   1.4
# 2                    4.7                  3.2                   1.3
# 3                    4.6                  3.1                   1.5
# 4                    5.0                  3.6                   1.4
# 5                    5.4                  3.9                   1.7
# 6                    4.6                  3.4                   1.4
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 9                    4.9                  3.1                   1.5
# 10                   5.4                  3.7                   1.5
# 11                   4.8                  3.4                   1.6
# 12                   4.8                  3.0                   1.4
# 13                   4.3                  3.0                   1.1
# 14                   5.8                  4.0                   1.2
# 15                   5.7                  4.4                   1.5
# 16                   5.4                  3.9                   1.3
# 17                   5.1                  3.5                   1.4
# 18                   5.7                  3.8                   1.7
# 19                   5.1                  3.8                   1.5
# 20                   5.4                  3.4                   1.7
# 21                   5.1                  3.7                   1.5
# 22                   4.6                  3.6                   1.0
# 23                   5.1                  3.3                   1.7
# 24                   4.8                  3.4                   1.9
# 25                   5.0                  3.0                   1.6
# 26                   5.0                  3.4                   1.6
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
# 30                   4.8                  3.1                   1.6
# 31                   5.4                  3.4                   1.5
# 32                   5.2                  4.1                   1.5
# 33                   5.5                  4.2                   1.4
# 34                   4.9                  3.1                   1.5
# 35                   5.0                  3.2                   1.2
# 36                   5.5                  3.5                   1.3
# 37                   4.9                  3.1                   1.5
# 38                   4.4                  3.0                   1.3
# 39                   5.1                  3.4                   1.5
# 40                   5.0                  3.5                   1.3
# 41                   4.5                  2.3                   1.3
# 42                   4.4                  3.2                   1.3
# 43                   5.0                  3.5                   1.6
# 44                   5.1                  3.8                   1.9
# 45                   4.8                  3.0                   1.4
# 46                   5.1                  3.8                   1.6
# 47                   4.6                  3.2                   1.4
# 48                   5.3                  3.7                   1.5
# 49                   5.0                  3.3                   1.4
#
#     Petal width (in cm)        Class
# 0                   0.2  Iris-setosa
# 1                   0.2  Iris-setosa
# 2                   0.2  Iris-setosa
# 3                   0.2  Iris-setosa
# 4                   0.2  Iris-setosa
# 5                   0.4  Iris-setosa
# 6                   0.3  Iris-setosa
# 7                   0.2  Iris-setosa
# 8                   0.2  Iris-setosa
# 9                   0.1  Iris-setosa
# 10                  0.2  Iris-setosa
# 11                  0.2  Iris-setosa
# 12                  0.1  Iris-setosa
# 13                  0.1  Iris-setosa
# 14                  0.2  Iris-setosa
# 15                  0.4  Iris-setosa
# 16                  0.4  Iris-setosa
# 17                  0.3  Iris-setosa
# 18                  0.3  Iris-setosa
# 19                  0.3  Iris-setosa
# 20                  0.2  Iris-setosa
# 21                  0.4  Iris-setosa
# 22                  0.2  Iris-setosa
# 23                  0.5  Iris-setosa
# 24                  0.2  Iris-setosa
# 25                  0.2  Iris-setosa
# 26                  0.4  Iris-setosa
# 27                  0.2  Iris-setosa
# 28                  0.2  Iris-setosa
# 29                  0.2  Iris-setosa
# 30                  0.2  Iris-setosa
# 31                  0.4  Iris-setosa
# 32                  0.1  Iris-setosa
# 33                  0.2  Iris-setosa
# 34                  0.1  Iris-setosa
# 35                  0.2  Iris-setosa
# 36                  0.2  Iris-setosa
# 37                  0.1  Iris-setosa
# 38                  0.2  Iris-setosa
# 39                  0.2  Iris-setosa
# 40                  0.3  Iris-setosa
# 41                  0.3  Iris-setosa
# 42                  0.2  Iris-setosa
# 43                  0.6  Iris-setosa
# 44                  0.4  Iris-setosa
# 45                  0.3  Iris-setosa
# 46                  0.2  Iris-setosa
# 47                  0.2  Iris-setosa
# 48                  0.2  Iris-setosa
# 49                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris['SepalExtra']= (Iris['Sepal Length (in cm)'] * Iris['Sepal Width in (cm)'])
Iris.head(5)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class  SepalExtra
# 0                  0.2  Iris-setosa       17.85
# 1                  0.2  Iris-setosa       14.70
# 2                  0.2  Iris-setosa       15.04
# 3                  0.2  Iris-setosa       14.26
# 4                  0.2  Iris-setosa       18.00

# %%
fn=lambda Iris:(Iris['Sepal Length (in cm)'] * Iris['Sepal Width in (cm)'])
col = Iris.apply(fn, axis=1)
Iris = Iris.assign(SepalExtra=col.values)
Iris.head(n=5)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class  SepalExtra
# 0                  0.2  Iris-setosa       17.85
# 1                  0.2  Iris-setosa       14.70
# 2                  0.2  Iris-setosa       15.04
# 3                  0.2  Iris-setosa       14.26
# 4                  0.2  Iris-setosa       18.00

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
Iris.mean()
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64

# %%
Iris.var()
# Out:
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def accept_two(x,y):
    print(x,"and",y)

# %%
accept_two(Iris.loc[4,'Sepal Length (in cm)'],Iris.loc[4,'Sepal Width in (cm)'])
# Out:
# 5.0 and 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
# range of sepal length
a=Iris['Sepal Length (in cm)'].max()
b=Iris['Sepal Length (in cm)'].min()
range_sepal_length=a-b
print(range_sepal_length)
# Out:
# 3.6000000000000005

# %%
# range of sepal width
a=Iris['Sepal Width in (cm)'].max()
b=Iris['Sepal Width in (cm)'].min()
range_sepal_width=a-b
print(range_sepal_width)
# Out:
# 2.4000000000000004

# %%
# range of petal length
a=Iris['Petal length (in cm)'].max()
b=Iris['Petal length (in cm)'].min()
range_petal_length=a-b
print(range_petal_length)
# Out:
# 5.9

# %%
# range of petal width
a=Iris['Petal width (in cm)'].max()
b=Iris['Petal width (in cm)'].min()
range_petal_width=a-b
print(range_petal_width)
# Out:
# 2.4

# %%
# range of SepalExtra
a=Iris['SepalExtra'].max()
b=Iris['SepalExtra'].min()
range_SepalExtra=a-b
print(range_SepalExtra)
# Out:
# 20.02

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
Iris=Iris.sort_values('Petal width (in cm)')

# %%
Iris.head(n=10)
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                   5.2                  4.1                   1.5
# 13                   4.3                  3.0                   1.1
# 37                   4.9                  3.1                   1.5
# 9                    4.9                  3.1                   1.5
# 12                   4.8                  3.0                   1.4
# 34                   4.9                  3.1                   1.5
# 0                    5.1                  3.5                   1.4
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
#
#     Petal width (in cm)        Class  SepalExtra
# 32                  0.1  Iris-setosa       21.32
# 13                  0.1  Iris-setosa       12.90
# 37                  0.1  Iris-setosa       15.19
# 9                   0.1  Iris-setosa       15.19
# 12                  0.1  Iris-setosa       14.40
# 34                  0.1  Iris-setosa       15.19
# 0                   0.2  Iris-setosa       17.85
# 27                  0.2  Iris-setosa       18.20
# 28                  0.2  Iris-setosa       17.68
# 29                  0.2  Iris-setosa       15.04

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
Iris.drop(columns='SepalExtra')
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                    5.2                  4.1                   1.5
# 13                    4.3                  3.0                   1.1
# 37                    4.9                  3.1                   1.5
# 9                     4.9                  3.1                   1.5
# 12                    4.8                  3.0                   1.4
# 34                    4.9                  3.1                   1.5
# 0                     5.1                  3.5                   1.4
# 27                    5.2                  3.5                   1.5
# 28                    5.2                  3.4                   1.4
# 29                    4.7                  3.2                   1.6
# 30                    4.8                  3.1                   1.6
# 33                    5.5                  4.2                   1.4
# 36                    5.5                  3.5                   1.3
# 38                    4.4                  3.0                   1.3
# 39                    5.1                  3.4                   1.5
# 42                    4.4                  3.2                   1.3
# 46                    5.1                  3.8                   1.6
# 47                    4.6                  3.2                   1.4
# 48                    5.3                  3.7                   1.5
# 49                    5.0                  3.3                   1.4
# 25                    5.0                  3.0                   1.6
# 24                    4.8                  3.4                   1.9
# 35                    5.0                  3.2                   1.2
# 3                     4.6                  3.1                   1.5
# 2                     4.7                  3.2                   1.3
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 10                    5.4                  3.7                   1.5
# 4                     5.0                  3.6                   1.4
# 11                    4.8                  3.4                   1.6
# ..                    ...                  ...                   ...
# 111                   6.4                  2.7                   5.3
# 121                   5.6                  2.8                   4.9
# 122                   7.7                  2.8                   6.7
# 147                   6.5                  3.0                   5.2
# 113                   5.7                  2.5                   5.0
# 131                   7.9                  3.8                   6.4
# 110                   6.5                  3.2                   5.1
# 139                   6.9                  3.1                   5.4
# 102                   7.1                  3.0                   5.9
# 112                   6.8                  3.0                   5.5
# 105                   7.6                  3.0                   6.6
# 124                   6.7                  3.3                   5.7
# 128                   6.4                  2.8                   5.6
# 117                   7.7                  3.8                   6.7
# 132                   6.4                  2.8                   5.6
# 104                   6.5                  3.0                   5.8
# 120                   6.9                  3.2                   5.7
# 115                   6.4                  3.2                   5.3
# 148                   6.2                  3.4                   5.4
# 141                   6.9                  3.1                   5.1
# 143                   6.8                  3.2                   5.9
# 145                   6.7                  3.0                   5.2
# 118                   7.7                  2.6                   6.9
# 135                   7.7                  3.0                   6.1
# 136                   6.3                  3.4                   5.6
# 140                   6.7                  3.1                   5.6
# 114                   5.8                  2.8                   5.1
# 100                   6.3                  3.3                   6.0
# 144                   6.7                  3.3                   5.7
# 109                   7.2                  3.6                   6.1
#
#      Petal width (in cm)           Class
# 32                   0.1     Iris-setosa
# 13                   0.1     Iris-setosa
# 37                   0.1     Iris-setosa
# 9                    0.1     Iris-setosa
# 12                   0.1     Iris-setosa
# 34                   0.1     Iris-setosa
# 0                    0.2     Iris-setosa
# 27                   0.2     Iris-setosa
# 28                   0.2     Iris-setosa
# 29                   0.2     Iris-setosa
# 30                   0.2     Iris-setosa
# 33                   0.2     Iris-setosa
# 36                   0.2     Iris-setosa
# 38                   0.2     Iris-setosa
# 39                   0.2     Iris-setosa
# 42                   0.2     Iris-setosa
# 46                   0.2     Iris-setosa
# 47                   0.2     Iris-setosa
# 48                   0.2     Iris-setosa
# 49                   0.2     Iris-setosa
# 25                   0.2     Iris-setosa
# 24                   0.2     Iris-setosa
# 35                   0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 7                    0.2     Iris-setosa
# 8                    0.2     Iris-setosa
# 10                   0.2     Iris-setosa
# 4                    0.2     Iris-setosa
# 11                   0.2     Iris-setosa
# ..                   ...             ...
# 111                  1.9  Iris-virginica
# 121                  2.0  Iris-virginica
# 122                  2.0  Iris-virginica
# 147                  2.0  Iris-virginica
# 113                  2.0  Iris-virginica
# 131                  2.0  Iris-virginica
# 110                  2.0  Iris-virginica
# 139                  2.1  Iris-virginica
# 102                  2.1  Iris-virginica
# 112                  2.1  Iris-virginica
# 105                  2.1  Iris-virginica
# 124                  2.1  Iris-virginica
# 128                  2.1  Iris-virginica
# 117                  2.2  Iris-virginica
# 132                  2.2  Iris-virginica
# 104                  2.2  Iris-virginica
# 120                  2.3  Iris-virginica
# 115                  2.3  Iris-virginica
# 148                  2.3  Iris-virginica
# 141                  2.3  Iris-virginica
# 143                  2.3  Iris-virginica
# 145                  2.3  Iris-virginica
# 118                  2.3  Iris-virginica
# 135                  2.3  Iris-virginica
# 136                  2.4  Iris-virginica
# 140                  2.4  Iris-virginica
# 114                  2.4  Iris-virginica
# 100                  2.5  Iris-virginica
# 144                  2.5  Iris-virginica
# 109                  2.5  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
#to get first 3 columns and top 10 rows
Iris.loc[0:10, ['Sepal Length (in cm)', 'Sepal Width in (cm)','Petal length (in cm)']]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                    5.1                  3.5                   1.4
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
# 30                   4.8                  3.1                   1.6
# 33                   5.5                  4.2                   1.4
# 36                   5.5                  3.5                   1.3
# 38                   4.4                  3.0                   1.3
# 39                   5.1                  3.4                   1.5
# 42                   4.4                  3.2                   1.3
# 46                   5.1                  3.8                   1.6
# 47                   4.6                  3.2                   1.4
# 48                   5.3                  3.7                   1.5
# 49                   5.0                  3.3                   1.4
# 25                   5.0                  3.0                   1.6
# 24                   4.8                  3.4                   1.9
# 35                   5.0                  3.2                   1.2
# 3                    4.6                  3.1                   1.5
# 2                    4.7                  3.2                   1.3
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 10                   5.4                  3.7                   1.5

# %%
IrisSubset= pd.DataFrame(data=Iris.loc[0:10, ['Sepal Length (in cm)', 'Sepal Width in (cm)','Petal length (in cm)']] )
IrisSubset
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                    5.1                  3.5                   1.4
# 27                   5.2                  3.5                   1.5
# 28                   5.2                  3.4                   1.4
# 29                   4.7                  3.2                   1.6
# 30                   4.8                  3.1                   1.6
# 33                   5.5                  4.2                   1.4
# 36                   5.5                  3.5                   1.3
# 38                   4.4                  3.0                   1.3
# 39                   5.1                  3.4                   1.5
# 42                   4.4                  3.2                   1.3
# 46                   5.1                  3.8                   1.6
# 47                   4.6                  3.2                   1.4
# 48                   5.3                  3.7                   1.5
# 49                   5.0                  3.3                   1.4
# 25                   5.0                  3.0                   1.6
# 24                   4.8                  3.4                   1.9
# 35                   5.0                  3.2                   1.2
# 3                    4.6                  3.1                   1.5
# 2                    4.7                  3.2                   1.3
# 7                    5.0                  3.4                   1.5
# 8                    4.4                  2.9                   1.4
# 10                   5.4                  3.7                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
HR=pd.read_csv('HR_external.txt',delimiter="\t",)
HR.head()
#delimiter is an alternate name for sep
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                 1          2               1              1
# 1                 8          1               1              1
# 2                 2          2               6              1
# 3                 3          4               1              1
# 4                 2          1               2              1
#
#            ...           RelationshipSatisfaction  StandardHours  \
# 0          ...                                  1             80
# 1          ...                                  4             80
# 2          ...                                  2             80
# 3          ...                                  3             80
# 4          ...                                  4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# # Print the no of rows and columns in the dataset

# %%
HR.shape
# Out:
# (1470, 35)

# %%
# nos of rows
HR.shape[0]
# Out:
# 1470

# %%
#nos of cols
HR.shape[1]
# Out:
# 35

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
HR.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
HR.iloc[:,3:11]
# Out:
#       BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0                  1       1102           1                 1          2
# 1                  2        279           2                 8          1
# 2                  1       1373           2                 2          2
# 3                  2       1392           2                 3          4
# 4                  1        591           2                 2          1
# 5                  2       1005           2                 2          2
# 6                  1       1324           2                 3          3
# 7                  1       1358           2                24          1
# 8                  2        216           2                23          3
# 9                  1       1299           2                27          3
# 10                 1        809           2                16          3
# 11                 1        153           2                15          2
# 12                 1        670           2                26          1
# 13                 1       1346           2                19          2
# 14                 1        103           2                24          3
# 15                 1       1389           2                21          4
# 16                 1        334           2                 5          2
# 17                 3       1123           2                16          2
# 18                 1       1219           1                 2          4
# 19                 1        371           2                 2          3
# 20                 3        673           2                11          2
# 21                 1       1218           1                 9          4
# 22                 1        419           2                 7          4
# 23                 1        391           2                15          2
# 24                 1        699           2                 6          1
# 25                 1       1282           2                 5          3
# 26                 2       1125           2                16          1
# 27                 1        691           1                 8          4
# 28                 1        477           2                 7          4
# 29                 1        705           1                 2          4
# ...              ...        ...         ...               ...        ...
# 1440               2        688           2                 4          2
# 1441               3        667           2                 1          4
# 1442               1       1092           2                 1          4
# 1443               1        300           2                 2          3
# 1444               1        310           2                 7          2
# 1445               1        582           2                28          4
# 1446               1        704           1                28          3
# 1447               3        301           1                15          4
# 1448               1        930           1                 3          3
# 1449               1        529           2                 2          3
# 1450               1       1146           3                26          4
# 1451               1        345           1                10          2
# 1452               2        878           1                 1          4
# 1453               1       1120           1                11          4
# 1454               1        374           1                20          3
# 1455               1       1322           2                 2          4
# 1456               2       1199           2                18          4
# 1457               1       1194           2                 2          4
# 1458               1        287           2                 1          4
# 1459               1       1378           2                13          2
# 1460               1        468           2                28          4
# 1461               1        410           1                28          3
# 1462               1        722           1                24          1
# 1463               3        325           2                 5          3
# 1464               1       1167           1                 5          3
# 1465               2        884           2                23          2
# 1466               1        613           2                 6          1
# 1467               1        155           2                 4          3
# 1468               2       1023           1                 2          3
# 1469               1        628           2                 8          3
#
#       EducationField  EmployeeCount  EmployeeNumber
# 0                  1              1               1
# 1                  1              1               2
# 2                  6              1               4
# 3                  1              1               5
# 4                  2              1               7
# 5                  1              1               8
# 6                  2              1              10
# 7                  1              1              11
# 8                  1              1              12
# 9                  2              1              13
# 10                 2              1              14
# 11                 1              1              15
# 12                 1              1              16
# 13                 2              1              18
# 14                 1              1              19
# 15                 1              1              20
# 16                 1              1              21
# 17                 2              1              22
# 18                 1              1              23
# 19                 1              1              24
# 20                 6              1              26
# 21                 1              1              27
# 22                 1              1              28
# 23                 1              1              30
# 24                 2              1              31
# 25                 6              1              32
# 26                 1              1              33
# 27                 3              1              35
# 28                 2              1              36
# 29                 3              1              38
# ...              ...            ...             ...
# 1440               1              1            2025
# 1441               1              1            2026
# 1442               2              1            2027
# 1443               1              1            2031
# 1444               4              1            2032
# 1445               1              1            2034
# 1446               3              1            2035
# 1447               3              1            2036
# 1448               1              1            2037
# 1449               4              1            2038
# 1450               1              1            2040
# 1451               1              1            2041
# 1452               1              1            2044
# 1453               3              1            2045
# 1454               1              1            2046
# 1455               1              1            2048
# 1456               1              1            2049
# 1457               2              1            2051
# 1458               1              1            2052
# 1459               6              1            2053
# 1460               2              1            2054
# 1461               3              1            2055
# 1462               3              1            2056
# 1463               2              1            2057
# 1464               6              1            2060
# 1465               2              1            2061
# 1466               2              1            2062
# 1467               1              1            2064
# 1468               2              1            2065
# 1469               2              1            2068
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
# HR['Gender'].value_counts() gives total number of 1s and 2s present in the gender column
#option 1
sum=0
for i in HR['Gender']:
    if i==1:
        sum=sum+1
print("Number of males in HR dataset =",sum)
# Out:
# Number of males in HR dataset = 882

# %%
sum=0
for i in HR['Gender']:
    if i==2:
        sum=sum+1
print("Number of females in HR dataset =",sum)
# Out:
# Number of females in HR dataset = 588

# %%
#option 2
print("Number of males in HR dataset =",HR['Gender'].value_counts()[1])
print("Number of females in HR dataset =",HR['Gender'].value_counts()[2])
# Out:
# Number of males in HR dataset = 882
# Number of females in HR dataset = 588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
q1, q3= np.percentile(HR.Age, [25,75])

# %%
iqr = q3 - q1
print("Interquartile range=",iqr)
# Out:
# Interquartile range= 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
s=HR['DailyRate'].mean()
w=HR['DailyRate'].median()
q=HR['DailyRate'].var()
print("Mean of DailyRate column= ",s,'\n'
      "Median of DailyRate column= ",w,'\n'
      "Variance of DailyRate column=",q)
# Out:
# Mean of DailyRate column=  802.4857142857143
# Median of DailyRate column=  802.0
# Variance of DailyRate column= 162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
HR['Attrition']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
# 5        No
# 6        No
# 7        No
# 8        No
# 9        No
# 10       No
# 11       No
# 12       No
# 13       No
# 14      Yes
# 15       No
# 16       No
# 17       No
# 18       No
# 19       No
# 20       No
# 21      Yes
# 22       No
# 23       No
# 24      Yes
# 25       No
# 26      Yes
# 27       No
# 28       No
# 29       No
#        ...
# 1440     No
# 1441     No
# 1442    Yes
# 1443     No
# 1444    Yes
# 1445     No
# 1446     No
# 1447     No
# 1448     No
# 1449     No
# 1450     No
# 1451     No
# 1452    Yes
# 1453     No
# 1454     No
# 1455     No
# 1456     No
# 1457     No
# 1458     No
# 1459     No
# 1460     No
# 1461    Yes
# 1462     No
# 1463     No
# 1464     No
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
sns.countplot(HR['Attrition'])

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
plt.plot(HR['TotalWorkingYears'],color='red')
