# %%
import numpy as np
import pandas as pd

# %%
laliga=pd.read_csv('Laliga.csv')

# %%
laliga.head()
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# 0        Pos             Team    Seasons     Points  GamesPlayed   GamesWon
# 1          1      Real Madrid         86       4385         2762       1647
# 2          2        Barcelona         86       4262         2762       1581
# 3          3  Atletico Madrid         80       3442         2614       1241
# 4          4         Valencia         82       3386         2664       1187
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8    Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0  GamesDrawn  GamesLost   GoalsFor  GoalsAgainst    Champion   Runner-up
# 1         552        563       5947          3140          33          23
# 2         573        608       5900          3114          25          25
# 3         598        775       4534          3309          10           8
# 4         616        861       4398          3469           6           6
#
# ...

# %%
laliga.rename(columns=laliga.iloc[0], inplace=True)

# %%
laliga.drop(0,inplace=True)

# %%
laliga
# Out:
#    Pos                 Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 1    1          Real Madrid      86   4385        2762     1647        552
# 2    2            Barcelona      86   4262        2762     1581        573
# 3    3      Atletico Madrid      80   3442        2614     1241        598
# 4    4             Valencia      82   3386        2664     1187        616
# 5    5      Athletic Bilbao      86   3368        2762     1209        633
# 6    6              Sevilla      73   2819        2408      990        531
# 7    7             Espanyol      82   2792        2626      948        608
# 8    8        Real Sociedad      70   2573        2302      864        577
# 9    9             Zaragoza      58   2109        1986      698        522
# 10  10           Real Betis      51   1884        1728      606        440
# 11  11  Deportivo La Coruna      45   1814        1530      563        392
# ...

# %%
laliga.tail()
# Out:
#    Pos              Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 57  57             Xerez       1     34          38        8         10
# 58  58            Condal       1     22          30        7          8
# 59  59   Atletico Tetuan       1     19          30        7          5
# 60  60  Cultural Leonesa       1     14          30        5          4
# 61  61            Girona       1      -           -        -          -
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# 57        20       38           66        -         -     -      -     -
# 58        15       37           57        -         -     -      -     -
# 59        18       51           85        -         -     -      -     -
# 60        21       34           65        -         -     -      -     -
# 61         -        -            -        -         -     -      -     -
#
#    Sixth  T    Debut Since/LastApp BestPosition
# ...

# %% [markdown]
# <h1>1) Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data. (2.5 points)
#     </h1>

# %%
laliga.describe()
# Out:
#        Pos    Team Seasons Points GamesPlayed GamesWon GamesDrawn GamesLost  \
# count   61      61      61     61          61       61         61        61
# unique  61      61      33     61          53       59         57        56
# top     20  Getafe       1    293        2762        8         16        37
# freq     1       1       6      1           3        2          2         3
#
#        GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth   T  \
# count        61           61       61        61    61     61    61    61  61
# unique       60           61        8        10     9      9     9     9  21
# top          70          253        -         -     -      -     -     -   -
# freq          2            1       52        48    43     39    36    33  28
#
#        Debut Since/LastApp BestPosition
# count     61            61           61
# unique    45            37           18
# top     1929       2015-16            1
# ...

# %%
laliga.replace(to_replace= '-', value= 0, inplace=True)

# %%
laliga
# Out:
#    Pos                 Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 1    1          Real Madrid      86   4385        2762     1647        552
# 2    2            Barcelona      86   4262        2762     1581        573
# 3    3      Atletico Madrid      80   3442        2614     1241        598
# 4    4             Valencia      82   3386        2664     1187        616
# 5    5      Athletic Bilbao      86   3368        2762     1209        633
# 6    6              Sevilla      73   2819        2408      990        531
# 7    7             Espanyol      82   2792        2626      948        608
# 8    8        Real Sociedad      70   2573        2302      864        577
# 9    9             Zaragoza      58   2109        1986      698        522
# 10  10           Real Betis      51   1884        1728      606        440
# 11  11  Deportivo La Coruna      45   1814        1530      563        392
# ...

# %%
laliga.describe()
# Out:
#        Pos    Team Seasons Points GamesPlayed GamesWon GamesDrawn GamesLost  \
# count   61      61      61     61          61       61         61        61
# unique  61      61      33     61          53       59         57        56
# top     20  Getafe       1    293        2762        8         16        37
# freq     1       1       6      1           3        2          2         3
#
#        GoalsFor GoalsAgainst  Champion  Runner-up  Third  Fourth  Fifth  \
# count        61           61        61         61     61      61     61
# unique       60           61         8         10      9       9      9
# top          70          253         0          0      0       0      0
# freq          2            1        52         48     43      39     36
#
#         Sixth   T Debut Since/LastApp BestPosition
# count      61  61    61            61           61
# unique      9  21    45            37           18
# top         0   0  1929       2015-16            1
# ...

# %% [markdown]
# <h> The dashes are replaced with zeros </h1>

# %% [markdown]
# <h1>
# 2) Print all the teams which have started playing between 1930-1980. (5 points)
# </h1>

# %%
debut_laliga=laliga[['Team','Debut']]

# %%
debut_btw_1930_and_1989=debut_laliga[debut_laliga['Debut']>=str(1930)]

# %%
teams_debut=debut_btw_1930_and_1989[debut_laliga['Debut']<=str(1980)]
print('The teams which have started playing between 1930-1980 are')
teams_debut
# Out:
# The teams which have started playing between 1930-1980 are
# D:\Python\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                    Team    Debut
# 4              Valencia  1931-32
# 6               Sevilla  1934-35
# 9              Zaragoza  1939-40
# 10           Real Betis  1932-33
# 11  Deportivo La Coruna  1941-42
# 12           Celta Vigo  1939-40
# 13           Valladolid  1948-49
# 15       Sporting Gijon  1944-45
# 16              Osasuna  1935-36
# 17               Malaga  1949-50
# 18               Oviedo  1933-34
# 19             Mallorca  1960-61
# 20           Las Palmas  1951-52
# 22              Granada  1941-42
# 23       Rayo Vallecano  1977-78
# 24                Elche  1959-60
# 26             Hercules  1935-36
# 27             Tenerife  1961-62
# 28               Murcia  1940-41
# 29               Alaves  1930-31
# ...

# %% [markdown]
# <h1>3) Print the list of teams which came Top 5 in terms of points (2.5 points)</h1>

# %%
np.dtype(laliga['Points'])
# Out:
# dtype('O')

# %%
laliga['Points'] = laliga['Points'].apply(pd.to_numeric) 
print(laliga['Points'].dtypes)
# Out:
# int64

# %%
x=laliga.nlargest(5, ['Points']) 
x
# Out:
#   Pos             Team Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 1   1      Real Madrid      86    4385        2762     1647        552
# 2   2        Barcelona      86    4262        2762     1581        573
# 3   3  Atletico Madrid      80    3442        2614     1241        598
# 4   4         Valencia      82    3386        2664     1187        616
# 5   5  Athletic Bilbao      86    3368        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 1       563     5947         3140       33        23     8      8     3     4
# 2       608     5900         3114       25        25    12     12     4     6
# 3       775     4534         3309       10         8    16      9     7     6
# 4       861     4398         3469        6         6    10     11    10     7
# 5       920     4631         3700        8         7    10      5     8    10
#
#     T    Debut Since/LastApp BestPosition
# ...

# %%
l1=[]
l1.append(x['Team'])

# %%
print('The list of teams which came Top 5 in terms of points are :','\n',l1)
# Out:
# The list of teams which came Top 5 in terms of points are :
#  [1        Real Madrid
# 2          Barcelona
# 3    Atletico Madrid
# 4           Valencia
# 5    Athletic Bilbao
# Name: Team, dtype: object]

# %% [markdown]
# <h1>
# 4) Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference. (5 points)
# </h1>
# <h2>
# Goal_diff_count = GoalsFor - GoalsAgainst
#     </h2>

# %%
np.dtype(laliga['GoalsFor'])
# Out:
# dtype('O')

# %%
np.dtype(laliga['GoalsAgainst'])
# Out:
# dtype('O')

# %%
laliga[['GoalsFor','GoalsAgainst']] = laliga[['GoalsFor','GoalsAgainst']].apply(pd.to_numeric) 
print(laliga[['GoalsFor','GoalsAgainst']].dtypes)
# to convert dtypes from object to int
# Out:
# GoalsFor        int64
# GoalsAgainst    int64
# dtype: object

# %%
def Goal_diff_count():
    difference = abs(laliga['GoalsFor'] - laliga['GoalsAgainst']) ## abs is for getting absolute values as here we get some negative values as difference
    laliga['Goal Difference']=difference
    x=laliga[['Team','Goal Difference']]
    print('The teams and their respecti e goal differences are:','\n',x)
    max_goal=laliga['Goal Difference'].max()
    maximum_goal=laliga[laliga["Goal Difference"]==max_goal]
    print('The team which has maximum goal difference is: ' , '\n',maximum_goal[['Team','Goal Difference']])
    min_goal=laliga['Goal Difference'].min()
    minimum_goal=laliga[laliga["Goal Difference"]==min_goal]
    print('The team which has minimum goal difference is: ' , '\n',minimum_goal[['Team','Goal Difference']])

# %%
Goal_diff_count()
# Out:
# The teams and their respecti e goal differences are:
#                     Team  Goal Difference
# 1           Real Madrid             2807
# 2             Barcelona             2786
# 3       Atletico Madrid             1225
# 4              Valencia              929
# 5       Athletic Bilbao              931
# 6               Sevilla              307
# 7              Espanyol              280
# 8         Real Sociedad                2
# 9              Zaragoza              164
# 10           Real Betis              333
# 11  Deportivo La Coruna              136
# 12           Celta Vigo              346
# 13           Valladolid              413
# 14     Racing Santander              525
# 15       Sporting Gijon              399
# 16              Osasuna              334
# 17               Malaga              342
# 18               Oviedo              309
# 19             Mallorca              189
# 20           Las Palmas              399
# ...

# %% [markdown]
# <h1> 5) Create a new column with name “Winning Percent” and append it to the data set (5 points)
# Percentage of Winning = (GamesWon / GamesPlayed)*100
#
# If there are any numerical error, replace it with 0%
#
# Print the top 5 teams which has the highest Winning percentage </h1>

# %%
laliga['GamesPlayed'].dtype
# Out:
# dtype('O')

# %%
laliga['GamesWon'].dtype
# Out:
# dtype('O')

# %%
laliga[['GamesWon','GamesPlayed']] = laliga[['GamesWon','GamesPlayed']].apply(pd.to_numeric) 
print(laliga[['GamesWon','GamesPlayed']].dtypes)
# Out:
# GamesWon       int64
# GamesPlayed    int64
# dtype: object

# %%
laliga['Winning Percent']=(laliga['GamesWon']/laliga['GamesPlayed'])*100

# %%
laliga
# Out:
#    Pos                 Team Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 1    1          Real Madrid      86    4385         2762      1647        552
# 2    2            Barcelona      86    4262         2762      1581        573
# 3    3      Atletico Madrid      80    3442         2614      1241        598
# 4    4             Valencia      82    3386         2664      1187        616
# 5    5      Athletic Bilbao      86    3368         2762      1209        633
# 6    6              Sevilla      73    2819         2408       990        531
# 7    7             Espanyol      82    2792         2626       948        608
# 8    8        Real Sociedad      70    2573         2302       864        577
# 9    9             Zaragoza      58    2109         1986       698        522
# 10  10           Real Betis      51    1884         1728       606        440
# 11  11  Deportivo La Coruna      45    1814         1530       563        392
# ...

# %%
# fill na values
laliga.fillna(value=0, inplace=True)

# %%
win=laliga.sort_values('Winning Percent',ascending=False)[:5]

# %%
print('The top 5 teams which has the highest Winning percentage','\n')
win
# Out:
# The top 5 teams which has the highest Winning percentage
#   Pos             Team Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 1   1      Real Madrid      86    4385         2762      1647        552
# 2   2        Barcelona      86    4262         2762      1581        573
# 3   3  Atletico Madrid      80    3442         2614      1241        598
# 4   4         Valencia      82    3386         2664      1187        616
# 5   5  Athletic Bilbao      86    3368         2762      1209        633
#
#   GamesLost  GoalsFor  GoalsAgainst       ...       Third Fourth Fifth Sixth  \
# 1       563      5947          3140       ...           8      8     3     4
# 2       608      5900          3114       ...          12     12     4     6
# 3       775      4534          3309       ...          16      9     7     6
# 4       861      4398          3469       ...          10     11    10     7
# 5       920      4631          3700       ...          10      5     8    10
#
# ...

# %% [markdown]
# <h1>
#     6) Group teams based on their “Best position” and print the sum of their points for all positions (5 points)
# Eg: Best Position                Points
#
#         1                              25000
#
#         2                              7000
#  </h1>

# %%
laliga['BestPosition'] = laliga['BestPosition'].apply(pd.to_numeric)

# %%
laliga['BestPosition'].dtype
# Out:
# dtype('int64')

# %%
grp=laliga[['BestPosition','Points']]
q=grp.groupby('BestPosition')
q.sum()
# Out:
#               Points
# BestPosition
# 1              27933
# 2               6904
# 3               5221
# 4               6563
# 5               1884
# 6               2113
# 7               1186
# 8               1134
# 9                 96
# 10               450
# 11               445
# 12               511
# 14                71
# 15                14
# 16                81
# 17               266
# 19                81
# 20                34
